# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('version_14/metrics.csv')

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['epoch'], df['train_loss_epoch'], label='Training Loss')
plt.plot(df['epoch'], df['val_loss_epoch'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['epoch'], df['train_acc_epoch'], label='Training Accuracy')
plt.plot(df['epoch'], df['val_acc_epoch'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['epoch'], df['learning_rate'], label='Learning Rate')
plt.xlabel('Epoch')
plt.ylabel('Learning Rate')
plt.title('Learning Rate')
plt.legend()
plt.show()

# %%
valid_val_loss = metrics_df.dropna(subset=['val_loss'])
valid_train_loss = metrics_df.dropna(subset=['train_loss_epoch'])

plt.plot(metrics_df['epoch'], metrics_df['train_loss_epoch'], label='Train Loss (Epoch)', color='blue')
plt.plot(valid_val_loss['epoch'], valid_val_loss['val_loss'], label='Validation Loss', color='red', marker='o')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
valid_val_acc = metrics_df.dropna(subset=['val_acc'])

#plt.plot(metrics_df['epoch'], metrics_df['train_acc_epoch'], label='Train Accuracy (Epoch)', color='blue')
plt.plot(valid_val_loss['epoch'], valid_val_acc['val_acc'], label='Validation Accuracy', color='red', marker='o')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
